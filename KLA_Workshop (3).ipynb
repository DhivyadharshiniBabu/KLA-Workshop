# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import pandas as pd

# %%
img1=cv.imread('/content/wafer_image_1.png')

# %%
img2=cv.imread('/content/wafer_image_2.png')

# %%
img3=cv.imread('/content/wafer_image_3.png')

# %%
img4=cv.imread('/content/wafer_image_4.png')

# %%
img5=cv.imread('/content/wafer_image_5.png')

# %%
print(img1.shape)
print(img2.shape)
print(img3.shape)
print(img4.shape)
print(img5.shape)
# Out:
# (600, 800, 3)
# (600, 800, 3)
# (600, 800, 3)
# (600, 800, 3)
# (600, 800, 3)

# %%
px=img1[100,100]
print(px)
# Out:
# [128 128 128]

# %%
grayimg1=cv.cvtColor(img1,cv.COLOR_BGR2GRAY)
plt.imshow(grayimg1,cmap='gray')

# %%
se=cv.getStructuringElement(cv.MORPH_RECT , (8,8))
bg=cv.morphologyEx(grayimg1, cv.MORPH_DILATE, se)
out_gray=cv.divide(grayimg1, bg, scale=255)
out_binary=cv.threshold(out_gray, 0, 255, cv.THRESH_OTSU )[1]

cv.imshow('binary', out_binary)
cv.imwrite('binary.png',out_binary)

cv.imshow('gray', out_gray)
cv.imwrite('gray.png',out_gray)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-45-ecf16ceadb4a> in <cell line: 6>()
#       4 out_binary=cv.threshold(out_gray, 0, 255, cv.THRESH_OTSU )[1]
#       5
# ----> 6 cv.imshow('binary', out_binary)
#       7 cv.imwrite('binary.png',out_binary)
#       8
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
grayimg2=cv.cvtColor(img2,cv.COLOR_BGR2GRAY)
plt.imshow(grayimg2,cmap='gray')

# %%
grayimg3=cv.cvtColor(img3,cv.COLOR_BGR2GRAY)
plt.imshow(grayimg3,cmap='gray')

# %%
grayimg4=cv.cvtColor(img4,cv.COLOR_BGR2GRAY)
plt.imshow(grayimg4,cmap='gray')

# %%
grayimg5=cv.cvtColor(img5,cv.COLOR_BGR2GRAY)
plt.imshow(grayimg5,cmap='gray')

# %%
arr1=[]
for i in range(len(grayimg1)):
  for j in range(len(grayimg1[i])):
    if(grayimg1[i][j]!=128 and grayimg1[i][j]!=255):
            arr1.append([1,j,i])
print(arr1)
# Out:
# [[1, 30, 0], [1, 85, 0], [1, 235, 0], [1, 273, 0], [1, 671, 0], [1, 100, 1], [1, 228, 1], [1, 316, 1], [1, 524, 1], [1, 544, 1], [1, 63, 2], [1, 196, 2], [1, 296, 2], [1, 350, 2], [1, 366, 2], [1, 457, 2], [1, 656, 2], [1, 658, 2], [1, 767, 2], [1, 782, 2], [1, 786, 2], [1, 31, 3], [1, 163, 3], [1, 201, 3], [1, 619, 3], [1, 643, 3], [1, 759, 3], [1, 27, 4], [1, 156, 4], [1, 197, 4], [1, 216, 4], [1, 542, 4], [1, 646, 4], [1, 653, 4], [1, 692, 4], [1, 798, 4], [1, 21, 5], [1, 136, 5], [1, 312, 5], [1, 315, 5], [1, 645, 5], [1, 671, 5], [1, 745, 5], [1, 72, 6], [1, 92, 6], [1, 153, 6], [1, 292, 6], [1, 346, 6], [1, 362, 6], [1, 424, 6], [1, 497, 6], [1, 543, 6], [1, 64, 7], [1, 109, 7], [1, 211, 7], [1, 297, 7], [1, 390, 7], [1, 632, 7], [1, 157, 8], [1, 267, 8], [1, 409, 8], [1, 471, 8], [1, 485, 8], [1, 584, 8], [1, 616, 8], [1, 641, 8], [1, 682, 8], [1, 692, 8], [1, 771, 8], [1, 67, 9], [1, 353, 9], [1, 610, 9], [1, 698, 9], [1, 720, 9], [1, 25, 10], [1, 111, 10], [1, 204, 10], [1, 
# ...

# %%
arr2=[]
'''for i in img2:
  arr2=np.array(i)
print(arr2)
DF2=pd.DataFrame(arr2)
DF.to_csv('img2_data.csv')'''
for i in range(len(grayimg2)):
  for j in range(len(grayimg2[i])):
    if(grayimg2[i][j]!=128 and grayimg2[i][j]!=255):
          arr2.append([1,j,i])
print(arr2)
# Out:
# [[1, 72, 0], [1, 220, 0], [1, 565, 0], [1, 657, 0], [1, 743, 0], [1, 38, 1], [1, 96, 1], [1, 107, 1], [1, 115, 1], [1, 150, 1], [1, 315, 1], [1, 361, 1], [1, 618, 1], [1, 631, 1], [1, 23, 2], [1, 51, 2], [1, 121, 2], [1, 293, 2], [1, 328, 2], [1, 330, 2], [1, 451, 2], [1, 533, 2], [1, 582, 2], [1, 689, 2], [1, 707, 2], [1, 25, 3], [1, 129, 3], [1, 131, 3], [1, 145, 3], [1, 172, 3], [1, 180, 3], [1, 205, 3], [1, 377, 3], [1, 378, 3], [1, 438, 3], [1, 447, 3], [1, 746, 3], [1, 58, 4], [1, 120, 4], [1, 619, 4], [1, 684, 4], [1, 709, 4], [1, 727, 4], [1, 140, 5], [1, 505, 5], [1, 517, 5], [1, 570, 5], [1, 773, 5], [1, 785, 5], [1, 792, 5], [1, 12, 6], [1, 85, 6], [1, 139, 6], [1, 160, 6], [1, 230, 6], [1, 356, 6], [1, 463, 6], [1, 559, 6], [1, 584, 6], [1, 52, 7], [1, 120, 7], [1, 128, 7], [1, 157, 7], [1, 225, 7], [1, 253, 7], [1, 261, 7], [1, 386, 7], [1, 464, 7], [1, 483, 7], [1, 518, 7], [1, 604, 7], [1, 58, 8], [1, 60, 8], [1, 71, 8], [1, 152, 8], [1, 172, 8], [1, 253, 8], [1, 279, 
# ...

# %%
arr3=[]
'''for i in img3:
  arr3=np.array(i)
print(arr3)
DF2=pd.DataFrame(arr3)
DF.to_csv('img3_data.csv')'''
for i in range(len(grayimg3)):
  for j in range(len(grayimg3[i])):
    if(grayimg3[i][j]!=128 and grayimg3[i][j]!=255):
          arr3.append([1,j,i])
print(arr3)
# Out:
# [[1, 86, 0], [1, 205, 0], [1, 237, 0], [1, 265, 0], [1, 394, 0], [1, 442, 0], [1, 450, 0], [1, 580, 0], [1, 736, 0], [1, 9, 1], [1, 193, 1], [1, 241, 1], [1, 269, 1], [1, 380, 1], [1, 555, 1], [1, 612, 1], [1, 655, 1], [1, 662, 1], [1, 710, 1], [1, 139, 2], [1, 203, 2], [1, 45, 3], [1, 68, 3], [1, 120, 3], [1, 139, 3], [1, 193, 3], [1, 213, 3], [1, 376, 3], [1, 564, 3], [1, 629, 3], [1, 677, 3], [1, 784, 3], [1, 55, 4], [1, 111, 4], [1, 397, 4], [1, 412, 4], [1, 36, 5], [1, 82, 5], [1, 99, 5], [1, 120, 5], [1, 131, 5], [1, 206, 5], [1, 223, 5], [1, 254, 5], [1, 539, 5], [1, 586, 5], [1, 680, 5], [1, 714, 5], [1, 753, 5], [1, 21, 6], [1, 46, 6], [1, 121, 6], [1, 320, 6], [1, 771, 6], [1, 24, 7], [1, 330, 7], [1, 352, 7], [1, 423, 7], [1, 587, 7], [1, 626, 7], [1, 394, 8], [1, 400, 8], [1, 505, 8], [1, 681, 8], [1, 696, 8], [1, 705, 8], [1, 82, 9], [1, 148, 9], [1, 401, 9], [1, 440, 9], [1, 672, 9], [1, 680, 9], [1, 687, 9], [1, 736, 9], [1, 773, 9], [1, 798, 9], [1, 77, 10], [1, 213, 
# ...

# %%
arr4=[]
'''for i in img4:
  arr4=np.array(i)
print(arr4)
DF2=pd.DataFrame(arr4)
DF.to_csv('img4_data.csv')'''
for i in range(len(grayimg4)):
  for j in range(len(grayimg4[i])):
    if(grayimg4[i][j]!=128 and grayimg4[i][j]!=255):
          arr4.append([1,j,i])
print(arr4)
# Out:
# [[1, 606, 0], [1, 608, 0], [1, 708, 0], [1, 4, 1], [1, 96, 1], [1, 239, 1], [1, 268, 1], [1, 295, 1], [1, 442, 1], [1, 547, 1], [1, 705, 1], [1, 32, 2], [1, 92, 2], [1, 157, 2], [1, 194, 2], [1, 265, 2], [1, 312, 2], [1, 397, 2], [1, 438, 2], [1, 587, 2], [1, 721, 2], [1, 31, 3], [1, 62, 3], [1, 390, 3], [1, 550, 3], [1, 642, 3], [1, 751, 3], [1, 100, 4], [1, 158, 4], [1, 263, 4], [1, 467, 4], [1, 597, 4], [1, 778, 4], [1, 780, 4], [1, 137, 5], [1, 346, 5], [1, 421, 5], [1, 429, 5], [1, 449, 5], [1, 521, 5], [1, 535, 5], [1, 617, 5], [1, 667, 5], [1, 18, 6], [1, 58, 6], [1, 577, 6], [1, 637, 6], [1, 654, 6], [1, 675, 6], [1, 9, 7], [1, 47, 7], [1, 50, 7], [1, 115, 7], [1, 271, 7], [1, 306, 7], [1, 309, 7], [1, 360, 7], [1, 419, 7], [1, 579, 7], [1, 775, 7], [1, 105, 8], [1, 116, 8], [1, 256, 8], [1, 264, 8], [1, 569, 8], [1, 632, 8], [1, 646, 8], [1, 675, 8], [1, 704, 8], [1, 62, 9], [1, 257, 9], [1, 337, 9], [1, 379, 9], [1, 472, 9], [1, 494, 9], [1, 496, 9], [1, 573, 9], [1, 636, 9
# ...

# %%
arr5=[]
'''finarr=[]
for i in img5:
  arr5=np.array(i)
  DF2=pd.DataFrame(arr5)
  break
DF2.to_csv('img5_data.csv')'''
for i in range(len(grayimg5)):
  for j in range(len(grayimg5[i])):
    if(grayimg5[i][j]!=128 and grayimg5[i][j]!=255):
      arr5.append([1,j,i])
print(arr5)
# Out:
# [[1, 222, 0], [1, 466, 0], [1, 601, 0], [1, 746, 0], [1, 7, 1], [1, 86, 1], [1, 132, 1], [1, 209, 1], [1, 365, 1], [1, 435, 1], [1, 532, 1], [1, 539, 1], [1, 563, 1], [1, 688, 1], [1, 732, 1], [1, 94, 2], [1, 204, 2], [1, 495, 2], [1, 503, 2], [1, 74, 3], [1, 251, 3], [1, 291, 3], [1, 321, 3], [1, 404, 3], [1, 441, 3], [1, 534, 3], [1, 541, 3], [1, 186, 4], [1, 225, 4], [1, 352, 4], [1, 455, 4], [1, 521, 4], [1, 42, 5], [1, 88, 5], [1, 96, 5], [1, 257, 5], [1, 298, 5], [1, 305, 5], [1, 363, 5], [1, 412, 5], [1, 426, 5], [1, 445, 5], [1, 616, 5], [1, 669, 5], [1, 185, 6], [1, 215, 6], [1, 220, 6], [1, 322, 6], [1, 356, 6], [1, 369, 6], [1, 421, 6], [1, 436, 6], [1, 439, 6], [1, 445, 6], [1, 662, 6], [1, 687, 6], [1, 722, 6], [1, 756, 6], [1, 76, 7], [1, 98, 7], [1, 100, 7], [1, 203, 7], [1, 321, 7], [1, 345, 7], [1, 480, 7], [1, 552, 7], [1, 586, 7], [1, 609, 7], [1, 654, 7], [1, 666, 7], [1, 694, 7], [1, 208, 8], [1, 633, 8], [1, 682, 8], [1, 737, 8], [1, 769, 8], [1, 11, 9], [1, 304
# ...

# %%
import csv
with open('anomalydata.csv','w') as f:
  csv_writer = csv.writer(f)
  csv_writer.writerows(arr1)
  csv_writer.writerows(arr2)
  csv_writer.writerows(arr3)
  csv_writer.writerows(arr4)
  csv_writer.writerows(arr5)
